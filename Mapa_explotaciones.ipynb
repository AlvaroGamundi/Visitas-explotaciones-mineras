# %%
import pandas as pd
import numpy as np
from janitor import clean_names
import folium

# %%
df=pd.read_csv('C:/Users/alvar/Desktop/Explotaciones_mineras/Analise_explotacions.csv',
               encoding='latin1',skiprows=1,index_col=0,parse_dates=['Fecha visita'],dayfirst=True)

# %%
def limpieza_datos(df):
    df=df.clean_names().drop(columns=['firmado','isa','anotaciones','unnamed_13','75_00_%','revisado','fecha_informe'])
    df['tipo_revision']=df.tipo_revision.replace(['visita'],'Visita')
    df=df.loc[df['tipo_revision']=='Visita']
    df['mes']=df['fecha_visita'].dt.month
    df['fecha_visita'] = df['fecha_visita'].dt.date
    
    return (df)

# %%
df=limpieza_datos(df)

# %%
def mapa(df):
    mapa=folium.Map(location= [42.7833,-7.8667],zoom_start=8.2)

    for explotacion in range(0,len(df)):
        folium.Marker(location=[df.iloc[explotacion]['latitud'],df.iloc[explotacion]['longitud']],
                 popup=f"Explotación: {df.index[explotacion]} Fecha Visita: {df.iloc[explotacion]['fecha_visita']}").add_to(mapa) 
    
    return (mapa)

# %%
mapa(df)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_44376336451b6d67162785bfcdb054a0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_44376336451b6d67162785bfcdb054a0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_44376336451b6d67162785bfcdb054a0 = L.map(
#                 &quot;map_44376336451b6d67162785bfcdb054a0&quot;,
#                 {
#                     center: [42.7833, -7.8667],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8.2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5c7126c612678cae682bd3310e96b561 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5c7126c612678cae682bd3310e96b561.addTo(map_44376336451b6d67162785bfcdb054a0);
#
#
#             var marker_78c28099daa7a9975f53a07092cdd8f5 = L.marker(
#                 [42.001953, -7.173331],
#                 {
# }
#             ).addTo(map_44376336451b6d67162785bfcdb054a0);
#
#
#         var popup_243b7271930d6ad8b0668149f0580067 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b4c3430b60d8274264320d4770298e6 = $(`&lt;div id=&quot;html_6b4c3430b60d8274264320d4770298e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Explotación: San Juan Fecha Visita: 2024-02-15&lt;/div&gt;`)[0];
#                 popup_243b7271930d6ad8b0668149f0580067.setContent(html_6b4c3430b60d8274264320d4770298e6);
#
#
#
#         marker_78c28099daa7a9975f53a07092cdd8f5.bindPopup(popup_243b7271930d6ad8b0668149f0580067)
#         ;
#
#
#
#
#             var marker_32d94dc7dfb434d4054aa466965cf7c6 = L.marker(
#                 [42.278924, -7.826714],
#                 {
# }
#             ).addTo(map_44376336451b6d67162785bfcdb054a0);
#
#
#         var popup_5edc9cf82abc15620d09e3dfa1b823bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_99b4a3496fc9089bd047818e6db14f02 = $(`&lt;div id=&quot;html_99b4a3496fc9089bd047818e6db14f02&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Explotación: Castroverde Fecha Visita: 2024-02-16&lt;/div&gt;`)[0];
#                 popup_5edc9cf82abc15620d09e3dfa1b823bc.setContent(html_99b4a3496fc9089bd047818e6db14f02);
#
#
#
#         marker_32d94dc7dfb434d4054aa466965cf7c6.bindPopup(popup_5edc9cf82abc15620d09e3dfa1b823bc)
#         ;
#
#
#
#
#             var marker_af0273af02432ff3d5d56cdbe7b77ff8 = L.marker(
#                 [42.269749, -8.247693],
#                 {
# }
#             ).addTo(map_44376336451b6d67162785bfcdb054a0);
#
#
#         var popup_6eda9b7cff224a7303bb61a4cfb4db86 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bd13ebd4fd5d38d0a7767f52f5a70cde = $(`&lt;div id=&quot;html_bd13ebd4fd5d38d0a7767f52f5a70cde&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Explotación: Faro I Fecha Visita: 2024-02-27&lt;/div&gt;`)[0];
#                 popup_6eda9b7cff224a7303bb61a4cfb4db86.setContent(html_bd13ebd4fd5d38d0a7767f52f5a70cde);
#
#
#
#         marker_af0273af02432ff3d5d56cdbe7b77ff8.bindPopup(popup_6eda9b7cff224a7303bb61a4cfb4db86)
#         ;
#
#
#
#
#             var marker_c173f15ae9a83f4b72d27df5fceec9db = L.marker(
#                 [42.271847, -8.24397],
#                 {
# }
#             ).addTo(map_44376336451b6d67162785bfcdb054a0);
#
#
#         var popup_311f082fbfa3f6606975d06e0632fbdf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_25d282349a3b7e3d990a497dc7e9e40f = $(`&lt;div id=&quot;html_25d282349a3b7e3d990a497dc7e9e40f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Explotación: Faro II Fecha Visita: 2024-02-27&lt;/div&gt;`)[0];
#                 popup_311f082fbfa3f6606975d06e0632fbdf.setContent(html_25d282349a3b7e3d990a497dc7e9e40f);
#
#
#
#         marker_c173f15ae9a83f4b72d27df5fceec9db.bindPopup(popup_311f082fbfa3f6606975d06e0632fbdf)
#         ;
#
#
#
#
#             var marker_87de9f019eb83dc5a14dd4e4eb8b91dd = L.marker(
#                 [42.075843, -7.773873],
#                 {
# }
#             ).addTo(map_44376336451b6d67162785bfcdb054a0);
#
#
#         var popup_4e75618c752662455be362db8f3f86fe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5dde806b164d72b366c7a6c800e913e0 = $(`&lt;div id=&quot;html_5dde806b164d72b366c7a6c800e913e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Explotación: Acibeiro Fecha Visita: 2024-02-29&lt;/div&gt;`)[0];
#                 popup_4e75618c752662455be362db8f3f86fe.setContent(html_5dde806b164d72b366c7a6c800e913e0);
#
#
#
#         marker_87de9f019eb83dc5a14dd4e4eb8b91dd.bindPopup(popup_4e75618c752662455be362db8f
